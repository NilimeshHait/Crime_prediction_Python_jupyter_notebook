# 521748   2019662777   2019662777540100          5401                       0
#
#                       OFFENSE_TYPE_ID           OFFENSE_CATEGORY_ID  \
# 0        weapon-unlawful-discharge-of              all-other-crimes
# 1                         theft-other                       larceny
# 2            theft-items-from-vehicle      theft-from-motor-vehicle
# 3                         theft-other                       larceny
# 4                      theft-shoplift                       larceny
# 5                          traf-other              all-other-crimes
# 6            theft-parts-from-vehicle      theft-from-motor-vehicle
# 7                criminal-trespassing              all-other-crimes
# 8        traffic-accident-hit-and-run              traffic-accident
# 9            theft-items-from-vehicle      theft-from-motor-vehicle
# 10        drug-methampetamine-possess                  drug-alcohol
# 11           theft-parts-from-vehicle      theft-from-motor-vehicle
# 12                     theft-shoplift                       larceny
# 13             theft-of-motor-vehicle                    auto-theft
# 14                     theft-shoplift                       larceny
# 15           theft-items-from-vehicle      theft-from-motor-vehicle
# 16             theft-of-motor-vehicle                    auto-theft
# 17               criminal-trespassing              all-other-crimes
# 18           fraud-by-use-of-computer            white-collar-crime
# 19                   traffic-accident              traffic-accident
# 20                         traf-other              all-other-crimes
# 21                   traffic-accident              traffic-accident
# 22       traffic-accident-hit-and-run              traffic-accident
# 23                         traf-other              all-other-crimes
# 24         burglary-business-by-force                      burglary
# 25                     theft-embezzle            white-collar-crime
# 26                  threats-to-injure               public-disorder
# 27                         traf-other              all-other-crimes
# 28             theft-of-motor-vehicle                    auto-theft
# 29               criminal-trespassing              all-other-crimes
# ...                               ...                           ...
# 521719       theft-parts-from-vehicle      theft-from-motor-vehicle
# 521720                theft-from-bldg                       larceny
# 521721               traffic-accident              traffic-accident
# 521722               traffic-accident              traffic-accident
# 521723    drug-methampetamine-possess                  drug-alcohol
# 521724                    theft-other                       larceny
# 521725       theft-items-from-vehicle      theft-from-motor-vehicle
# 521726            drug-pcs-other-drug                  drug-alcohol
# 521727       prostitution-engaging-in               public-disorder
# 521728       theft-items-from-vehicle      theft-from-motor-vehicle
# 521729               traffic-accident              traffic-accident
# 521730                  sex-aslt-rape                sexual-assault
# 521731               traffic-accident              traffic-accident
# 521732       theft-parts-from-vehicle      theft-from-motor-vehicle
# 521733  burg-auto-theft-resd-no-force                      burglary
# 521734         harassment-stalking-dv               public-disorder
# 521735        criminal-mischief-other               public-disorder
# 521736                     traf-other              all-other-crimes
# 521737       theft-items-from-vehicle      theft-from-motor-vehicle
# 521738       theft-parts-from-vehicle      theft-from-motor-vehicle
# 521739    burglary-residence-no-force                      burglary
# 521740               traffic-accident              traffic-accident
# 521741                 assault-simple  other-crimes-against-persons
# 521742                 theft-shoplift                       larceny
# 521743       theft-parts-from-vehicle      theft-from-motor-vehicle
# 521744      criminal-mischief-mtr-veh               public-disorder
# 521745       prostitution-engaging-in               public-disorder
# 521746                    theft-other                       larceny
# 521747       violation-of-court-order              all-other-crimes
# 521748   traffic-accident-hit-and-run              traffic-accident
#
#          FIRST_OCCURRENCE_DATE    LAST_OCCURRENCE_DATE  \
# 0        6/15/2016 11:31:00 PM                     NaN
# 1       10/11/2017 12:30:00 PM   10/11/2017 4:55:00 PM
# 17                    lincoln-park         1           0
# 18            washington-park-west         1           0
# 19                       stapleton         0           1
# 20                       stapleton         1           0
# 21                     lowry-field         0           1
# 22                     five-points         0           1
# 23                  elyria-swansea         1           0
# 24                       goldsmith         1           0
# 25                   hampden-south         1           0
# 26                             dia         1           0
# 27                      platt-park         1           0
# 28                     west-colfax         1           0
# 29                       stapleton         1           0
# ...                            ...       ...         ...
# 521719                         cbd         1           0
# 521720               union-station         1           0
# 521721                         cbd         0           1
# 521722                       speer         0           1
# 521723                       baker         1           0
# 521724  gateway-green-valley-ranch         1           0
# 521725                cory-merrill         1           0
# 521726               union-station         1           0
# 521727                 east-colfax         1           0
# 521728           harvey-park-south         1           0
# 521729               cheesman-park         0           1
# 521730                capitol-hill         1           0
# 521731                    berkeley         0           1
# 521732                    westwood         1           0
# 521733                    westwood         1           0
# 521734                 five-points         1           0
# 521735                 five-points         1           0
# 521736                  platt-park         1           0
# 521737                cory-merrill         1           0
# 521738                cory-merrill         1           0
# 521739                   city-park         1           0
# 521740                  platt-park         0           1
# 521741               union-station         1           0
# 521742                         cbd         1           0
# 521743                       baker         1           0
# 521744             south-park-hill         1           0
# 521745                 east-colfax         1           0
# 521746                   stapleton         1           0
# 521747                     skyland         1           0
# 521748                 lowry-field         0           1
#
# [521749 rows x 19 columns]

# %%
crime_dataset=crime_dataset[['OFFENSE_CATEGORY_ID','FIRST_OCCURRENCE_DATE','NEIGHBORHOOD_ID','IS_CRIME']]

# %%
crime_dataset[0:10]
# Out:
#         OFFENSE_CATEGORY_ID   FIRST_OCCURRENCE_DATE  \
# 0          all-other-crimes   6/15/2016 11:31:00 PM
# 1                   larceny  10/11/2017 12:30:00 PM
# 2  theft-from-motor-vehicle     3/4/2016 8:00:00 PM
# 3                   larceny    1/30/2018 7:20:00 PM
# 4                   larceny    6/22/2017 8:53:00 PM
# 5          all-other-crimes   1/31/2018 12:44:00 AM
# 6  theft-from-motor-vehicle    6/1/2017 12:15:00 PM
# 7          all-other-crimes    1/30/2018 7:40:00 AM
# 8          traffic-accident    1/30/2018 9:10:00 AM
# 9  theft-from-motor-vehicle   1/31/2018 12:55:00 AM
#
#               NEIGHBORHOOD_ID  IS_CRIME
# 0                   montbello         1
# 1  gateway-green-valley-ranch         1
# 2                   wellshire         1
# 3                     belcaro         1
# 4                cherry-creek         1
# 5              city-park-west         1
# 6                  villa-park         1
# 7                       speer         1
# 8                civic-center         0
# 9                    highland         1

# %%
crime_dataset['IS_CRIME'].value_counts()
# Out:
# 1    386017
# 0    135732
# Name: IS_CRIME, dtype: int64

# %%
crime_dataset.describe()
# Out:
#             IS_CRIME
# count  521749.000000
# mean        0.739852
# std         0.438716
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %%
#remove all the irrelevant onces
crime_dataset=crime_dataset.drop(crime_dataset[crime_dataset.IS_CRIME ==0].index)

# %%
crime_dataset.count()
# Out:
# OFFENSE_CATEGORY_ID      386017
# FIRST_OCCURRENCE_DATE    386017
# NEIGHBORHOOD_ID          386017
# IS_CRIME                 386017
# dtype: int64

# %%
#rename the columns

#crime_dataset=crime_dataset.rename(columns={"OFFENSE_CATEGORY_ID":"Crime_Type","FIRST_OCCURRENCE_DATE":"Crime_Date","NEIGHBORHOOD_ID":
#                                           "Crime_Location"})

# %%
crime_dataset[0:5]
# Out:
#         OFFENSE_CATEGORY_ID   FIRST_OCCURRENCE_DATE  \
# 0          all-other-crimes   6/15/2016 11:31:00 PM
# 1                   larceny  10/11/2017 12:30:00 PM
# 2  theft-from-motor-vehicle     3/4/2016 8:00:00 PM
# 3                   larceny    1/30/2018 7:20:00 PM
# 4                   larceny    6/22/2017 8:53:00 PM
#
#               NEIGHBORHOOD_ID  IS_CRIME
# 0                   montbello         1
# 1  gateway-green-valley-ranch         1
# 2                   wellshire         1
# 3                     belcaro         1
# 4                cherry-creek         1

# %%
crime_dataset.groupby(crime_dataset['OFFENSE_CATEGORY_ID']).count()
# Out:
#                               FIRST_OCCURRENCE_DATE  NEIGHBORHOOD_ID  IS_CRIME
# OFFENSE_CATEGORY_ID
# aggravated-assault                            12440            12440     12440
# all-other-crimes                              94188            94188     94188
# arson                                           652              652       652
# auto-theft                                    27777            27777     27777
# burglary                                      25680            25680     25680
# drug-alcohol                                  34205            34205     34205
# larceny                                       52997            52997     52997
# murder                                          318              318       318
# other-crimes-against-persons                  25699            25699     25699
# public-disorder                               54217            54217     54217
# robbery                                        6782             6782      6782
# sexual-assault                                 4321             4321      4321
# theft-from-motor-vehicle                      39608            39608     39608
# white-collar-crime                             7133             7133      7133

# %%
crime_dataset['FIRST_OCCURRENCE_DATE'] = pd.to_datetime(crime_dataset['FIRST_OCCURRENCE_DATE'])

# %%
crime_dataset[0:10]
# Out:
#          OFFENSE_CATEGORY_ID FIRST_OCCURRENCE_DATE  \
# 0           all-other-crimes   2016-06-15 23:31:00
# 1                    larceny   2017-10-11 12:30:00
# 2   theft-from-motor-vehicle   2016-03-04 20:00:00
# 3                    larceny   2018-01-30 19:20:00
# 4                    larceny   2017-06-22 20:53:00
# 5           all-other-crimes   2018-01-31 00:44:00
# 6   theft-from-motor-vehicle   2017-06-01 12:15:00
# 7           all-other-crimes   2018-01-30 07:40:00
# 9   theft-from-motor-vehicle   2018-01-31 00:55:00
# 10              drug-alcohol   2018-01-30 20:04:00
#
#                NEIGHBORHOOD_ID  IS_CRIME
# 0                    montbello         1
# 1   gateway-green-valley-ranch         1
# 2                    wellshire         1
# 3                      belcaro         1
# 4                 cherry-creek         1
# 5               city-park-west         1
# 6                   villa-park         1
# 7                        speer         1
# 9                     highland         1
# 10                   goldsmith         1

# %%
#ADD Column Month
import calendar
crime_dataset['Month'] = crime_dataset['FIRST_OCCURRENCE_DATE'].dt.month.apply(lambda x: calendar.month_name[x])

# %%
#adding column Crime day
crime_dataset['Crime_Day'] = crime_dataset['FIRST_OCCURRENCE_DATE'].dt.weekday_name

# %%
crime_dataset=crime_dataset.rename(columns={"NEIGHBORHOOD_ID":"Crime_Location"})

# %%
#adding column crime_type

arr1=['aggravated-assault','sexual-assault','other-crimes-against-persons','arson','murder']
arr2=['all-other-crimes']
arr3=['drug-alcohol']
arr4=['public-disorder']
arr5=['auto-theft','theft-from-motor-vehicle','burglary','larceny','robbery']
arr6=['white-collar-crime']
crime_dataset['Crime_Type']=np.where(crime_dataset['OFFENSE_CATEGORY_ID'].isin(arr1), 'Assault',
                                     np.where(crime_dataset['OFFENSE_CATEGORY_ID'].isin(arr2),'All other crimes',
                                              np.where(crime_dataset['OFFENSE_CATEGORY_ID'].isin(arr3), 'Drug/Alcohol',
                                                       np.where(crime_dataset['OFFENSE_CATEGORY_ID'].isin(arr4),'Public Disorder',
                                                                np.where(crime_dataset['OFFENSE_CATEGORY_ID'].isin(arr5),'Theft',
                                                                         np.where(crime_dataset['OFFENSE_CATEGORY_ID'].isin(arr6),
                                                                                  'White collar crime','none'))))))

# %%
crime_dataset.groupby([crime_dataset['Crime_Type']]).count()
# Out:
#                     OFFENSE_CATEGORY_ID  FIRST_OCCURRENCE_DATE  \
# Crime_Type
# All other crimes                  94188                  94188
# Assault                           43430                  43430
# Drug/Alcohol                      34205                  34205
# Public Disorder                   54217                  54217
# Theft                            152844                 152844
# White collar crime                 7133                   7133
#
#                     Crime_Location  IS_CRIME   Month  Crime_Day  Crime_Type
# Crime_Type
# All other crimes             94188     94188   94188      94188       94188
# Assault                      43430     43430   43430      43430       43430
# Drug/Alcohol                 34205     34205   34205      34205       34205
# Public Disorder              54217     54217   54217      54217       54217
# Theft                       152844    152844  152844     152844      152844
# White collar crime            7133      7133    7133       7133        7133

# %%
#Removeing 2019 data
crime_dataset=crime_dataset[crime_dataset['FIRST_OCCURRENCE_DATE'].dt.year<2019]

# %%
#adding crime_type_id column

arr1=['Assault']
arr2=['Drug/Alcohol']
arr3=['All other crimes']
arr4=['Public Disorder']
arr5=['Theft']
arr6=['White collar crime']

crime_dataset['Crime_Type_Id']=np.where(crime_dataset['Crime_Type'].isin(arr1), '1',
                                        np.where(crime_dataset['Crime_Type'].isin(arr2), '2',
                                                 np.where(crime_dataset['Crime_Type'].isin(arr3), '3',
                                                          np.where(crime_dataset['Crime_Type'].isin(arr4),'4',
                                                                   np.where(crime_dataset['Crime_Type'].isin(arr5),'5',
                                                                            np.where(crime_dataset['Crime_Type'].isin(arr6),'6',
                                                                                     'none'))))))

# %%
crime_dataset=crime_dataset.rename(columns={"FIRST_OCCURRENCE_DATE":"Crime_Date"})

# %%
#adding crime_time with grouping.

arr1=[1,2,3,4]
arr2=[5,6,7,8]
arr3=[9,10,11,12]
arr4=[13,14,15,16]
arr5=[17,18,19,20]
arr6=[21,22,23,0]

crime_dataset['Crime_time']=np.where(crime_dataset['Crime_Date'].dt.hour.isin(arr1), 'T1',
                                     np.where(crime_dataset['Crime_Date'].dt.hour.isin(arr2), 'T2',
                                              np.where(crime_dataset['Crime_Date'].dt.hour.isin(arr3), 'T3',
                                                       np.where(crime_dataset['Crime_Date'].dt.hour.isin(arr4),'T4',
                                                                np.where(crime_dataset['Crime_Date'].dt.hour.isin(arr5),
                                                                         'T5',np.where(crime_dataset['Crime_Date']
# 519941                       larceny 2018-09-01 12:00:00
# 520143            white-collar-crime 2018-10-19 08:00:00
# 520367              all-other-crimes 2018-12-26 16:00:00
# 520978            aggravated-assault 2018-10-04 08:54:00
#
#                     Crime_Location  IS_CRIME      Month  Crime_Day  \
# 0                        montbello         1       June  Wednesday
# 1       gateway-green-valley-ranch         1    October  Wednesday
# 2                        wellshire         1      March     Friday
# 3                          belcaro         1    January    Tuesday
# 4                     cherry-creek         1       June   Thursday
# 5                   city-park-west         1    January  Wednesday
# 6                       villa-park         1       June   Thursday
# 7                            speer         1    January    Tuesday
# 9                         highland         1    January  Wednesday
# 10                       goldsmith         1    January    Tuesday
# 11                       ruby-hill         1    January     Sunday
# 12                    cory-merrill         1        May    Tuesday
# 13                  jefferson-park         1   February     Friday
# 14                         windsor         1      April   Saturday
# 15                        highland         1        May     Sunday
# 16                       goldsmith         1       June     Friday
# 17                    lincoln-park         1    January     Monday
# 18            washington-park-west         1    January   Thursday
# 20                       stapleton         1    January    Tuesday
# 23                  elyria-swansea         1    January    Tuesday
# 24                       goldsmith         1    January     Monday
# 25                   hampden-south         1    October     Monday
# 26                             dia         1    January    Tuesday
# 27                      platt-park         1    January    Tuesday
# 28                     west-colfax         1        May   Saturday
# 29                       stapleton         1       June     Sunday
# 30               harvey-park-south         1    January    Tuesday
# 31                           baker         1        May  Wednesday
# 32                   cheesman-park         1    January   Thursday
# 33                             dia         1    January     Monday
# ...                            ...       ...        ...        ...
# 518168                      barnum         1   December   Thursday
# 518169                   montbello         1   December    Tuesday
# 518170         northeast-park-hill         1   December     Sunday
# 518171                     hampden         1   December  Wednesday
# 518172                         cbd         1   December     Monday
# 518174                        hale         1   December   Saturday
# 518176                        hale         1   December     Friday
# 518177                 five-points         1   December   Thursday
# 518178                 five-points         1   December     Friday
# 518180                    highland         1   December     Sunday
# 518182                 five-points         1   December  Wednesday
# 518183                     mar-lee         1   December     Monday
# 518184                   ruby-hill         1   December     Friday
# 518185                       regis         1   December   Thursday
# 518186                 five-points         1   December    Tuesday
# 518188                   montbello         1   December    Tuesday
# 518189                  globeville         1   December     Monday
# 518190            virginia-village         1   December   Saturday
# 518191                 west-colfax         1   December   Saturday
# 518193               congress-park         1   December    Tuesday
# 518194                         dia         1   November     Monday
# 518196                 west-colfax         1   December     Sunday
# 518197            university-hills         1   December  Wednesday
# 518832                lincoln-park         1   November   Thursday
# 519102                   sunnyside         1    October    Tuesday
# 519281                lincoln-park         1   November   Thursday
# 519941                 east-colfax         1  September   Saturday
# 520143                         cbd         1    October     Friday
# 520367                civic-center         1   December  Wednesday
# 520978                 lowry-field         1    October   Thursday
#
#                 Crime_Type Crime_Type_Id Crime_time
# 0         All other crimes             3         T6
# 1                    Theft             5         T3
# 2                    Theft             5         T5
# 3                    Theft             5         T5
# 4                    Theft             5         T5
# 5         All other crimes             3         T6
# 6                    Theft             5         T3
# 7         All other crimes             3         T2
# 9                    Theft             5         T6
# 10            Drug/Alcohol             2         T5
# 11                   Theft             5         T2
# 12                   Theft             5         T4
# 13                   Theft             5         T4
# 14                   Theft             5         T4
# 15                   Theft             5         T1
# 16                   Theft             5         T6
# 17        All other crimes             3         T4
# 18      White collar crime             6         T3
# 20        All other crimes             3         T3
# 23        All other crimes             3         T3
# 24                   Theft             5         T6
# 25      White collar crime             6         T3
# 26         Public Disorder             4         T4
# 27        All other crimes             3         T3
# 28                   Theft             5         T6
# 29        All other crimes             3         T5
# 30                   Theft             5         T5
# 31                   Theft             5         T3
# 32                   Theft             5         T4
# 33                   Theft             5         T2
# ...                    ...           ...        ...
# 518168        Drug/Alcohol             2         T6
# 518169    All other crimes             3         T5
# 518170             Assault             1         T3
# 518171               Theft             5         T2
# 518172             Assault             1         T1
# 518174     Public Disorder             4         T6
# 518176               Theft             5         T4
# 518177     Public Disorder             4         T2
# 518178               Theft             5         T6
# 518180               Theft             5         T5
# 518182     Public Disorder             4         T5
# 518183    All other crimes             3         T2
# 518184               Theft             5         T6
# 518185               Theft             5         T5
# 518186    All other crimes             3         T1
# 518188    All other crimes             3         T4
# 518189    All other crimes             3         T6
# 518190               Theft             5         T4
# 518191               Theft             5         T2
# 518193    All other crimes             3         T5
# 518194  White collar crime             6         T4
# 518196    All other crimes             3         T2
# 518197               Theft             5         T4
# 518832             Assault             1         T6
# 519102  White collar crime             6         T4
# 519281             Assault             1         T6
# 519941               Theft             5         T3
# 520143  White collar crime             6         T2
# 520367    All other crimes             3         T4
# 520978             Assault             1         T2
#
# [333447 rows x 9 columns]

# %%
#rename the columns

#crime_dataset=crime_dataset.rename(columns={"Crime_Type":"OFFENSE_CATEGORY_ID","Crime_Date":"FIRST_OCCURRENCE_DATE"})

# %%
crime_dataset
# Out:
#                  OFFENSE_CATEGORY_ID          Crime_Date  \
# 0                   all-other-crimes 2016-06-15 23:31:00
# 1                            larceny 2017-10-11 12:30:00
# 2           theft-from-motor-vehicle 2016-03-04 20:00:00
# 3                            larceny 2018-01-30 19:20:00
# 4                            larceny 2017-06-22 20:53:00
# 5                   all-other-crimes 2018-01-31 00:44:00
# 6           theft-from-motor-vehicle 2017-06-01 12:15:00
# 7                   all-other-crimes 2018-01-30 07:40:00
# 9           theft-from-motor-vehicle 2018-01-31 00:55:00
# 10                      drug-alcohol 2018-01-30 20:04:00
# 11          theft-from-motor-vehicle 2018-01-28 05:25:00
# 12                           larceny 2016-05-31 16:54:00
# 13                        auto-theft 2017-02-24 16:55:00
# 14                           larceny 2016-04-16 15:25:00
# 15          theft-from-motor-vehicle 2017-05-28 02:00:00
# 16                        auto-theft 2017-06-16 21:30:00
# 17                  all-other-crimes 2018-01-29 14:50:00
# 18                white-collar-crime 2018-01-04 12:00:00
# 20                  all-other-crimes 2018-01-30 11:27:00
# 23                  all-other-crimes 2018-01-30 12:30:00
# 24                          burglary 2018-01-29 21:30:00
# 25                white-collar-crime 2017-10-30 12:00:00
# 26                   public-disorder 2018-01-30 14:30:00
# 27                  all-other-crimes 2018-01-30 11:50:00
# 28                        auto-theft 2017-05-06 00:00:00
# 29                  all-other-crimes 2016-06-12 20:00:00
# ...                            ...       ...        ...        ...
# 518168                      barnum         1   December   Thursday
# 518169                   montbello         1   December    Tuesday
# 518170         northeast-park-hill         1   December     Sunday
# 518171                     hampden         1   December  Wednesday
# 518172                         cbd         1   December     Monday
# 518174                        hale         1   December   Saturday
# 518176                        hale         1   December     Friday
# 518177                 five-points         1   December   Thursday
# 518178                 five-points         1   December     Friday
# 518180                    highland         1   December     Sunday
# 518182                 five-points         1   December  Wednesday
# 518183                     mar-lee         1   December     Monday
# 518184                   ruby-hill         1   December     Friday
# 518185                       regis         1   December   Thursday
# 518186                 five-points         1   December    Tuesday
# 518188                   montbello         1   December    Tuesday
# 518189                  globeville         1   December     Monday
# 518190            virginia-village         1   December   Saturday
# 518191                 west-colfax         1   December   Saturday
# 518193               congress-park         1   December    Tuesday
# 518194                         dia         1   November     Monday
# 518196                 west-colfax         1   December     Sunday
# 518197            university-hills         1   December  Wednesday
# 518832                lincoln-park         1   November   Thursday
# 519102                   sunnyside         1    October    Tuesday
# 519281                lincoln-park         1   November   Thursday
# 519941                 east-colfax         1  September   Saturday
# 520143                         cbd         1    October     Friday
# 520367                civic-center         1   December  Wednesday
# 520978                 lowry-field         1    October   Thursday
#
#                 Crime_Type Crime_Type_Id Crime_time
# 0         All other crimes             3         T6
# 1                    Theft             5         T3
# 2                    Theft             5         T5
# 3                    Theft             5         T5
# 4                    Theft             5         T5
# 5         All other crimes             3         T6
# 6                    Theft             5         T3
# 7         All other crimes             3         T2
# 9                    Theft             5         T6
# 10            Drug/Alcohol             2         T5
# 11                   Theft             5         T2
# 12                   Theft             5         T4
# 13                   Theft             5         T4
# 14                   Theft             5         T4
# 15                   Theft             5         T1
# 16                   Theft             5         T6
# 17        All other crimes             3         T4
# 18      White collar crime             6         T3
# 20        All other crimes             3         T3
# 23        All other crimes             3         T3
# 24                   Theft             5         T6
# 25      White collar crime             6         T3
# 26         Public Disorder             4         T4
# 27        All other crimes             3         T3
# 28                   Theft             5         T6
# 29        All other crimes             3         T5
# 30                   Theft             5         T5
# 31                   Theft             5         T3
# 32                   Theft             5         T4
# 33                   Theft             5         T2
# ...                    ...           ...        ...
# 518168        Drug/Alcohol             2         T6
# 518169    All other crimes             3         T5
# 518170             Assault             1         T3
# 518171               Theft             5         T2
# 518172             Assault             1         T1
# 518174     Public Disorder             4         T6
# 518176               Theft             5         T4
# 518177     Public Disorder             4         T2
# 518178               Theft             5         T6
# 518180               Theft             5         T5
# 518182     Public Disorder             4         T5
# 518183    All other crimes             3         T2
# 518184               Theft             5         T6
# 518185               Theft             5         T5
# 518186    All other crimes             3         T1
# 518188    All other crimes             3         T4
# 518189    All other crimes             3         T6
# 518190               Theft             5         T4
# 518191               Theft             5         T2
# 518193    All other crimes             3         T5
# 518194  White collar crime             6         T4
# 518196    All other crimes             3         T2
# 518197               Theft             5         T4
# 518832             Assault             1         T6
# 519102  White collar crime             6         T4
# 519281             Assault             1         T6
# 519941               Theft             5         T3
# 520143  White collar crime             6         T2
# 520367    All other crimes             3         T4
# 520978             Assault             1         T2
#
# [333447 rows x 9 columns]

# %%
#Yearly Crime Percentage 

yearly_crime_rate=crime_dataset.groupby(crime_dataset['Crime_Date'].dt.year).count()

yearly_crime_rate_percnt=(yearly_crime_rate/len(crime_dataset)*100)

Yearly=yearly_crime_rate_percnt[['IS_CRIME']].plot(kind='bar',title ="Percentage Of Crime Occurrence Over 5 Years", figsize=(10,4), legend=True, fontsize=12)
Yearly.set_xlabel('Year')
Yearly.set_ylabel('Number of crime(%)')

plt.show()

# %%
# Crime lelong to 2018

crime_2018=crime_dataset[crime_dataset['Crime_Date'].dt.year==2018]
monthly_crime_rate=crime_2018.groupby(crime_2018['Month']).count()

monthly_crime_rate_percnt=(monthly_crime_rate/len(crime_2018)*100)

monthly=monthly_crime_rate_percnt[['IS_CRIME']].plot(kind='bar',title ="Percentage Of Crime Occurrence Over 12 Months (Year=2018)", figsize=(10,4), legend=True, fontsize=12)
monthly.set_xlabel('Month')
monthly.set_ylabel('Number of crime(%)')

plt.show()

# %%
by_days_crime_rate=crime_2018.groupby(crime_2018['Crime_Day']).count()

by_days_crime_rate_percnt=(by_days_crime_rate/len(crime_2018)*100)

by_days=by_days_crime_rate_percnt[['IS_CRIME']].plot(kind='bar',title ="Percentage Of Crime Occurrence Over the week (Year=2018)", figsize=(10,4), legend=True, fontsize=12,color="orange")
by_days.set_xlabel('Days')
by_days.set_ylabel('Number of crime(%)')

plt.show()

# %%
by_time_crime_rate=crime_2018.groupby(crime_2018['Crime_time']).count()

by_time_crime_rate_percnt=(by_time_crime_rate/len(crime_2018)*100)

by_time=by_time_crime_rate_percnt[['IS_CRIME']].plot(kind='bar',title ="Percentage Of Crime Occurrence Over 4 hours intervals (Year=2018)", figsize=(10,4), legend=True, fontsize=12,color="crimson")
by_time.set_xlabel('Days')
by_time.set_ylabel('Number of crime(%)')

plt.show()

# %%
by_time_crime_rate=crime_2018.groupby(crime_2018['Crime_Location']).count()

by_time_crime_rate_percnt=(by_time_crime_rate/len(crime_2018)*100)
by_time_crime_rate_percnt=by_time_crime_rate_percnt.sort_values(by=['IS_CRIME'])
by_time=by_time_crime_rate_percnt[['IS_CRIME']].plot(kind='bar',title ="Percentage Of Crime Occurrence Over 78 Neighborhood (Year=2018)", figsize=(15,4), legend=True, fontsize=12,color="crimson")
by_time.set_xlabel('Neighborhood')
by_time.set_ylabel('Number of crime(%)')

plt.show()

# %%
crime_2018.groupby([crime_dataset['Crime_Type']]).count()
# Out:
#                     OFFENSE_CATEGORY_ID  Crime_Date  Crime_Location  IS_CRIME  \
# Crime_Type
# All other crimes                  17613       17613           17613     17613
# Assault                            7538        7538            7538      7538
# Drug/Alcohol                       6132        6132            6132      6132
# Public Disorder                    8575        8575            8575      8575
# Theft                             28018       28018           28018     28018
# White collar crime                 1285        1285            1285      1285
#
#                     Month  Crime_Day  Crime_Type  Crime_Type_Id  Crime_time
# Crime_Type
# All other crimes    17613      17613       17613          17613       17613
# Assault              7538       7538        7538           7538        7538
# Drug/Alcohol         6132       6132        6132           6132        6132
# Public Disorder      8575       8575        8575           8575        8575
# Theft               28018      28018       28018          28018       28018
# White collar crime   1285       1285        1285           1285        1285

# %%
Theft=(crime_2018[(crime_2018.Crime_Type=="Theft") & (crime_2018.Crime_Day=="Sunday")].OFFENSE_CATEGORY_ID.count()*100/28018,
    crime_2018[(crime_2018.Crime_Type=="Theft") & (crime_2018.Crime_Day=="Monday")].OFFENSE_CATEGORY_ID.count()*100/28018,
    crime_2018[(crime_2018.Crime_Type=="Theft") & (crime_2018.Crime_Day=="Tuesday")].OFFENSE_CATEGORY_ID.count()*100/28018,
    crime_2018[(crime_2018.Crime_Type=="Theft") & (crime_2018.Crime_Day=="Wednesday")].OFFENSE_CATEGORY_ID.count()*100/28018,
    crime_2018[(crime_2018.Crime_Type=="Theft") & (crime_2018.Crime_Day=="Thursday")].OFFENSE_CATEGORY_ID.count()*100/28018,
    crime_2018[(crime_2018.Crime_Type=="Theft") & (crime_2018.Crime_Day=="Friday")].OFFENSE_CATEGORY_ID.count()*100/28018,
    crime_2018[(crime_2018.Crime_Type=="Theft") & (crime_2018.Crime_Day=="Saturday")].OFFENSE_CATEGORY_ID.count()*100/28018)

All_other_crimes=(crime_2018[(crime_2018.Crime_Type=="All other crimes") & (crime_2018.Crime_Day=="Sunday")].OFFENSE_CATEGORY_ID.count()*100/17613,
    crime_2018[(crime_2018.Crime_Type=="All other crimes") & (crime_2018.Crime_Day=="Monday")].OFFENSE_CATEGORY_ID.count()*100/17613,
    crime_2018[(crime_2018.Crime_Type=="All other crimes") & (crime_2018.Crime_Day=="Tuesday")].OFFENSE_CATEGORY_ID.count()*100/17613,
    crime_2018[(crime_2018.Crime_Type=="All other crimes") & (crime_2018.Crime_Day=="Wednesday")].OFFENSE_CATEGORY_ID.count()*100/17613,
    crime_2018[(crime_2018.Crime_Type=="All other crimes") & (crime_2018.Crime_Day=="Thursday")].OFFENSE_CATEGORY_ID.count()*100/17613,
    crime_2018[(crime_2018.Crime_Type=="All other crimes") & (crime_2018.Crime_Day=="Friday")].OFFENSE_CATEGORY_ID.count()*100/17613,
    crime_2018[(crime_2018.Crime_Type=="All other crimes") & (crime_2018.Crime_Day=="Saturday")].OFFENSE_CATEGORY_ID.count()*100/17613)


Drug_Alcohol=(crime_2018[(crime_2018.Crime_Type=="Drug/Alcohol") & (crime_2018.Crime_Day=="Sunday")].OFFENSE_CATEGORY_ID.count()*100/6132,
    crime_2018[(crime_2018.Crime_Type=="Drug/Alcohol") & (crime_2018.Crime_Day=="Monday")].OFFENSE_CATEGORY_ID.count()*100/6132,
    crime_2018[(crime_2018.Crime_Type=="Drug/Alcohol") & (crime_2018.Crime_Day=="Tuesday")].OFFENSE_CATEGORY_ID.count()*100/6132,
    crime_2018[(crime_2018.Crime_Type=="Drug/Alcohol") & (crime_2018.Crime_Day=="Wednesday")].OFFENSE_CATEGORY_ID.count()*100/6132,
    crime_2018[(crime_2018.Crime_Type=="Drug/Alcohol") & (crime_2018.Crime_Day=="Thursday")].OFFENSE_CATEGORY_ID.count()*100/6132,
    crime_2018[(crime_2018.Crime_Type=="Drug/Alcohol") & (crime_2018.Crime_Day=="Friday")].OFFENSE_CATEGORY_ID.count()*100/6132,
    crime_2018[(crime_2018.Crime_Type=="Drug/Alcohol") & (crime_2018.Crime_Day=="Saturday")].OFFENSE_CATEGORY_ID.count()*100/6132)

Assault=(crime_2018[(crime_2018.Crime_Type=="Assault") & (crime_2018.Crime_Day=="Sunday")].OFFENSE_CATEGORY_ID.count()*100/7538,
    crime_2018[(crime_2018.Crime_Type=="Assault") & (crime_2018.Crime_Day=="Monday")].OFFENSE_CATEGORY_ID.count()*100/7538,
    crime_2018[(crime_2018.Crime_Type=="Assault") & (crime_2018.Crime_Day=="Tuesday")].OFFENSE_CATEGORY_ID.count()*100/7538,
    crime_2018[(crime_2018.Crime_Type=="Assault") & (crime_2018.Crime_Day=="Wednesday")].OFFENSE_CATEGORY_ID.count()*100/7538,
    crime_2018[(crime_2018.Crime_Type=="Assault") & (crime_2018.Crime_Day=="Thursday")].OFFENSE_CATEGORY_ID.count()*100/7538,
    crime_2018[(crime_2018.Crime_Type=="Assault") & (crime_2018.Crime_Day=="Friday")].OFFENSE_CATEGORY_ID.count()*100/7538,
    crime_2018[(crime_2018.Crime_Type=="Assault") & (crime_2018.Crime_Day=="Saturday")].OFFENSE_CATEGORY_ID.count()*100/7538)

Public_Disorder=(crime_2018[(crime_2018.Crime_Type=="Public Disorder") & (crime_2018.Crime_Day=="Sunday")].OFFENSE_CATEGORY_ID.count()*100/8575,
    crime_2018[(crime_2018.Crime_Type=="Public Disorder") & (crime_2018.Crime_Day=="Monday")].OFFENSE_CATEGORY_ID.count()*100/8575,
    crime_2018[(crime_2018.Crime_Type=="Public Disorder") & (crime_2018.Crime_Day=="Tuesday")].OFFENSE_CATEGORY_ID.count()*100/8575,
    crime_2018[(crime_2018.Crime_Type=="Public Disorder") & (crime_2018.Crime_Day=="Wednesday")].OFFENSE_CATEGORY_ID.count()*100/8575,
    crime_2018[(crime_2018.Crime_Type=="Public Disorder") & (crime_2018.Crime_Day=="Thursday")].OFFENSE_CATEGORY_ID.count()*100/8575,
    crime_2018[(crime_2018.Crime_Type=="Public Disorder") & (crime_2018.Crime_Day=="Friday")].OFFENSE_CATEGORY_ID.count()*100/8575,
    crime_2018[(crime_2018.Crime_Type=="Public Disorder") & (crime_2018.Crime_Day=="Saturday")].OFFENSE_CATEGORY_ID.count()*100/8575)

White_collar_crime=(crime_2018[(crime_2018.Crime_Type=="White collar crime") & (crime_2018.Crime_Day=="Sunday")].OFFENSE_CATEGORY_ID.count()*100/1285,
    crime_2018[(crime_2018.Crime_Type=="White collar crime") & (crime_2018.Crime_Day=="Monday")].OFFENSE_CATEGORY_ID.count()*100/1285,
    crime_2018[(crime_2018.Crime_Type=="White collar crime") & (crime_2018.Crime_Day=="Tuesday")].OFFENSE_CATEGORY_ID.count()*100/1285,
    crime_2018[(crime_2018.Crime_Type=="White collar crime") & (crime_2018.Crime_Day=="Wednesday")].OFFENSE_CATEGORY_ID.count()*100/1285,
    crime_2018[(crime_2018.Crime_Type=="White collar crime") & (crime_2018.Crime_Day=="Thursday")].OFFENSE_CATEGORY_ID.count()*100/1285,
    crime_2018[(crime_2018.Crime_Type=="White collar crime") & (crime_2018.Crime_Day=="Friday")].OFFENSE_CATEGORY_ID.count()*100/1285,
    crime_2018[(crime_2018.Crime_Type=="White collar crime") & (crime_2018.Crime_Day=="Saturday")].OFFENSE_CATEGORY_ID.count()*100/1285)

print(All_other_crimes)
print(Theft)
print(Drug_Alcohol)
print(Assault)
print(Public_Disorder)
print(White_collar_crime)

#crime_2018[(crime_2018.Crime_Type=="Theft")&(crime_2018.Crime_Day=="Thusday")].count()
# Out:
# (13.97263384999716, 13.626298756600239, 13.580877760744904, 14.171350706864247, 14.284903196502583, 16.090387781752113, 14.27354794753875)
# (12.941680348347491, 14.330073524163039, 13.933899635948318, 14.697694339353273, 14.765507887786423, 15.5542865300878, 13.776857734313655)
# (8.463796477495107, 14.677103718199609, 17.05805609915199, 17.40052185257665, 15.900195694716242, 15.753424657534246, 10.746901500326159)
# (17.53780843725126, 12.297691695409924, 12.231361103741046, 13.425311753780843, 13.133457150437781, 14.513133457150438, 16.86123640222871)
# (14.192419825072886, 13.772594752186588, 13.002915451895044, 14.693877551020408, 14.553935860058308, 15.113702623906706, 14.670553935860058)
# (7.937743190661479, 15.408560311284047, 16.264591439688715, 14.319066147859923, 16.88715953307393, 17.276264591439688, 11.906614785992218)

# %%
N=7

ind = np.arange(N)

plt.figure(figsize=(12, 5))
width =.1
plt.bar(ind, All_other_crimes, width, label='All_other_crimes')
plt.bar(ind + width, Drug_Alcohol, width,label='Drug_Alcohol')
plt.bar(ind + width+ width, Public_Disorder, width,label='Public_Disorder')
plt.bar(ind+ width+ width+ width, Assault, width, label='Assault')
plt.bar(ind + width+ width+ width+ width, White_collar_crime, width,label='White_collar_crime')
plt.bar(ind + width+ width+ width+ width+ width, Theft, width,label='Theft')


plt.ylabel('Percentage of Crime')
plt.title('Percentage of crimes over the days of the week in Denver(2018)')

plt.xticks(ind + width/7  , ('Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday','Friday','Saturday'))
plt.legend(loc='best', bbox_to_anchor=(0.5, 0.1, 0.5, 0.5))
plt.show()

# %%
Theft=(crime_2018[(crime_2018.Crime_Type=="Theft") & (crime_2018.Crime_time=="T1")].OFFENSE_CATEGORY_ID.count()*100/28018,
    crime_2018[(crime_2018.Crime_Type=="Theft") & (crime_2018.Crime_time=="T2")].OFFENSE_CATEGORY_ID.count()*100/28018,
    crime_2018[(crime_2018.Crime_Type=="Theft") & (crime_2018.Crime_time=="T3")].OFFENSE_CATEGORY_ID.count()*100/28018,
    crime_2018[(crime_2018.Crime_Type=="Theft") & (crime_2018.Crime_time=="T4")].OFFENSE_CATEGORY_ID.count()*100/28018,
    crime_2018[(crime_2018.Crime_Type=="Theft") & (crime_2018.Crime_time=="T5")].OFFENSE_CATEGORY_ID.count()*100/28018,
    crime_2018[(crime_2018.Crime_Type=="Theft") & (crime_2018.Crime_time=="T6")].OFFENSE_CATEGORY_ID.count()*100/28018)

All_other_crimes=(crime_2018[(crime_2018.Crime_Type=="All other crimes") & (crime_2018.Crime_time=="T1")].OFFENSE_CATEGORY_ID.count()*100/17613,
    crime_2018[(crime_2018.Crime_Type=="All other crimes") & (crime_2018.Crime_time=="T2")].OFFENSE_CATEGORY_ID.count()*100/17613,
    crime_2018[(crime_2018.Crime_Type=="All other crimes") & (crime_2018.Crime_time=="T3")].OFFENSE_CATEGORY_ID.count()*100/17613,
    crime_2018[(crime_2018.Crime_Type=="All other crimes") & (crime_2018.Crime_time=="T4")].OFFENSE_CATEGORY_ID.count()*100/17613,
    crime_2018[(crime_2018.Crime_Type=="All other crimes") & (crime_2018.Crime_time=="T5")].OFFENSE_CATEGORY_ID.count()*100/17613,
    crime_2018[(crime_2018.Crime_Type=="All other crimes") & (crime_2018.Crime_time=="T6")].OFFENSE_CATEGORY_ID.count()*100/17613)


Drug_Alcohol=(crime_2018[(crime_2018.Crime_Type=="Drug/Alcohol") & (crime_2018.Crime_time=="T1")].OFFENSE_CATEGORY_ID.count()*100/6132,
    crime_2018[(crime_2018.Crime_Type=="Drug/Alcohol") & (crime_2018.Crime_time=="T2")].OFFENSE_CATEGORY_ID.count()*100/6132,
    crime_2018[(crime_2018.Crime_Type=="Drug/Alcohol") & (crime_2018.Crime_time=="T3")].OFFENSE_CATEGORY_ID.count()*100/6132,
    crime_2018[(crime_2018.Crime_Type=="Drug/Alcohol") & (crime_2018.Crime_time=="T4")].OFFENSE_CATEGORY_ID.count()*100/6132,
    crime_2018[(crime_2018.Crime_Type=="Drug/Alcohol") & (crime_2018.Crime_time=="T5")].OFFENSE_CATEGORY_ID.count()*100/6132,
    crime_2018[(crime_2018.Crime_Type=="Drug/Alcohol") & (crime_2018.Crime_time=="T6")].OFFENSE_CATEGORY_ID.count()*100/6132)

Assault=(crime_2018[(crime_2018.Crime_Type=="Assault") & (crime_2018.Crime_time=="T1")].OFFENSE_CATEGORY_ID.count()*100/7538,
    crime_2018[(crime_2018.Crime_Type=="Assault") & (crime_2018.Crime_time=="T2")].OFFENSE_CATEGORY_ID.count()*100/7538,
    crime_2018[(crime_2018.Crime_Type=="Assault") & (crime_2018.Crime_time=="T3")].OFFENSE_CATEGORY_ID.count()*100/7538,
    crime_2018[(crime_2018.Crime_Type=="Assault") & (crime_2018.Crime_time=="T4")].OFFENSE_CATEGORY_ID.count()*100/7538,
    crime_2018[(crime_2018.Crime_Type=="Assault") & (crime_2018.Crime_time=="T5")].OFFENSE_CATEGORY_ID.count()*100/7538,
    crime_2018[(crime_2018.Crime_Type=="Assault") & (crime_2018.Crime_time=="T6")].OFFENSE_CATEGORY_ID.count()*100/7538)

Public_Disorder=(crime_2018[(crime_2018.Crime_Type=="Public Disorder") & (crime_2018.Crime_time=="T1")].OFFENSE_CATEGORY_ID.count()*100/8575,
    crime_2018[(crime_2018.Crime_Type=="Public Disorder") & (crime_2018.Crime_time=="T2")].OFFENSE_CATEGORY_ID.count()*100/8575,
    crime_2018[(crime_2018.Crime_Type=="Public Disorder") & (crime_2018.Crime_time=="T3")].OFFENSE_CATEGORY_ID.count()*100/8575,
    crime_2018[(crime_2018.Crime_Type=="Public Disorder") & (crime_2018.Crime_time=="T4")].OFFENSE_CATEGORY_ID.count()*100/8575,
    crime_2018[(crime_2018.Crime_Type=="Public Disorder") & (crime_2018.Crime_time=="T5")].OFFENSE_CATEGORY_ID.count()*100/8575,
    crime_2018[(crime_2018.Crime_Type=="Public Disorder") & (crime_2018.Crime_time=="T6")].OFFENSE_CATEGORY_ID.count()*100/8575)

White_collar_crime=(crime_2018[(crime_2018.Crime_Type=="White collar crime") & (crime_2018.Crime_time=="T1")].OFFENSE_CATEGORY_ID.count()*100/1285,
    crime_2018[(crime_2018.Crime_Type=="White collar crime") & (crime_2018.Crime_time=="T2")].OFFENSE_CATEGORY_ID.count()*100/1285,
    crime_2018[(crime_2018.Crime_Type=="White collar crime") & (crime_2018.Crime_time=="T3")].OFFENSE_CATEGORY_ID.count()*100/1285,
    crime_2018[(crime_2018.Crime_Type=="White collar crime") & (crime_2018.Crime_time=="T4")].OFFENSE_CATEGORY_ID.count()*100/1285,
    crime_2018[(crime_2018.Crime_Type=="White collar crime") & (crime_2018.Crime_time=="T5")].OFFENSE_CATEGORY_ID.count()*100/1285,
    crime_2018[(crime_2018.Crime_Type=="White collar crime") & (crime_2018.Crime_time=="T6")].OFFENSE_CATEGORY_ID.count()*100/1285)

print(All_other_crimes)
print(Theft)
print(Drug_Alcohol)
print(Assault)
print(Public_Disorder)
print(White_collar_crime)

#crime_2018[(crime_2018.Crime_Type=="Theft")&(crime_2018.Crime_time=="Thusday")].count()
# Out:
# (11.553965820700618, 7.948674274683473, 14.313291318912167, 21.353545676488956, 21.041276329983535, 23.78924657923125)
# (8.819330430437576, 12.33849668070526, 16.378756513669785, 18.30251980869441, 23.65979013491327, 20.5011064315797)
# (6.718851924331377, 5.071754729288976, 19.194390084801043, 32.615786040443574, 21.314416177429877, 15.084801043705154)
# (15.07031042716901, 8.88829928362961, 13.96922260546564, 18.081719288936057, 21.318652162377287, 22.671796232422395)
# (10.495626822157435, 10.145772594752186, 16.92128279883382, 17.516034985422742, 22.355685131195337, 22.565597667638485)
# (2.6459143968871595, 14.474708171206226, 28.638132295719846, 22.490272373540854, 14.863813229571985, 16.88715953307393)

# %%
N=6

ind = np.arange(N)

plt.figure(figsize=(12, 5))
width =.1
plt.bar(ind, All_other_crimes, width, label='All_other_crimes')
plt.bar(ind + width, Drug_Alcohol, width,label='Drug_Alcohol')
plt.bar(ind + width+ width, Public_Disorder, width,label='Public_Disorder')
plt.bar(ind+ width+ width+ width, Assault, width, label='Assault')
plt.bar(ind + width+ width+ width+ width, White_collar_crime, width,label='White_collar_crime')
plt.bar(ind + width+ width+ width+ width+ width, Theft, width,label='Theft')


plt.ylabel('Percentage of Crime')
plt.title('Percentage of crimes over the 4 hours interval in Denvar(2018)')

plt.xticks(ind + width/7  , ('1-4:59', '5-8:59', '9-12:59', '13-16:59', '17-20:59','19-0:59'))
plt.legend(loc='upper left')
plt.show()
